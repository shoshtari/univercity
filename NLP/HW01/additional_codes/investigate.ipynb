# %%
from final import *

# %%
evaluate_decoder(final_decoder, val_words, verbose=True)
# Out:
# 14 ooo
# 17 ebb
# 24 xn
# 15 mba
# 14 io
# 14 proverb
# 16 jap
# 21 vpn
# 17 brawl
# 14 va
# 17 yew
# 18 malawi
# 14 nabokov
# 19 yat
# 18 kit
# 17 kin
# 15 quota
# 16 sift
# 15 majority
# 19 kann
# 18 anjou
# 18 anwar
# 19 mazzini
# 17 vat
# 14 hooks
# 14 dac
# 16 fob
# 14 makers
# 19 uaw
# 16 quirk
# 14 lovejoy
# 16 dcs
# 14 sow
# 19 katz
# 18 kung
# 14 sawmill
# 15 book
# 15 yama
# 16 kohl
# 14 visnu
# 15 sanskrit
# 16 toi
# 17 jests
# 18 joy
# 15 cowper
# 23 dj
# 20 sv
# 16 jaw
# 16 gide
# 19 gb
# 15 oxide
# 16 ngc
# 16 jericho
# 14 majorities
# 14 javier
# 14 turquoise
# 15 ueber
# 15 saved
# 14 vast
# 24 xj
# 14 chao
# 16 jeremy
# 20 buffon
# 17 rye
# 14 wigwam
# 17 hl
# 14 haiku
# 15 fcc
# Words with error beyond threshold moved average around 1.113
# 6.514

# %%
decode_signal("keeper", final_decoder, max_errors=26)
# Out:
# Signal decoding started
# Target pattern: _ _ _ _ _ _ | Word length: 6
# Remaining allowed errors: 26
# Proposed character: s
# Wrong guess.
# Remaining allowed errors: 25
# Proposed character: e
# Correct guess: _ e e _ e _
# Remaining allowed errors: 25
# Proposed character: r
# Correct guess: _ e e _ e r
# Remaining allowed errors: 25
# Proposed character: t
# Wrong guess.
# Remaining allowed errors: 24
# Proposed character: d
# Wrong guess.
# Remaining allowed errors: 23
# Proposed character: n
# Wrong guess.
# Remaining allowed errors: 22
# Proposed character: p
# Correct guess: _ e e p e r
# Remaining allowed errors: 22
# Proposed character: l
# Wrong guess.
# Remaining allowed errors: 21
# Proposed character: k
# Correct guess: k e e p e r
# Decoding completed successfully.
# 5
