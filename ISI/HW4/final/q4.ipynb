# %%
from scipy import stats

# %%
critical_value = stats.chi2.ppf(0.99, df=4)
print(stats.chi2.cdf(critical_value, df=4))
print("Critical value", critical_value)
print(80 * 413.27)
# Out:
# 0.99
# Critical value 13.276704135987622
# 33061.6
