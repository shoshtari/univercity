# %%
import numpy as np
from scipy.stats import t

# %%
((1.64 + 6.25) ** 2) / (2.56 / 9 + 6.25 / 99)
# Out:
# 179.10368788142978

# %%
val = t.ppf(0.05, 179.10)
val
# Out:
# np.float64(-1.6534059973223263)
